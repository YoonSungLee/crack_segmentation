# %%
import os
import numpy as np
from custom_module import max_width, categorical_crack, img_show, crack_dist
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib as mpl

# %%
test_image_path = '/home/jovyan/work/hangman/dataset/crack_segmentation_dataset/minimal/test/images'
test_mask_path = '/home/jovyan/work/hangman/dataset/crack_segmentation_dataset/minimal/test/masks'
file_name = 'DeepCrack_11220-1.jpg'

img_show(os.path.join(test_image_path, file_name))
crack_dist(os.path.join(test_mask_path, file_name))
max_value = max_width(os.path.join(test_mask_path, file_name))
print('max width:', max_value)
print('crack grade:', categorical_crack(max_value))
# Out:
# max width: [ 9.99  4.39  4.39  5.6   6.    6.    5.6   4.39  6.    4.39  5.6   2.8
#   4.39  2.    2.8   4.    4.    6.    5.6   6.39  6.    6.39  7.19  6.39
#   6.39  6.    6.    6.    6.    6.    6.39  7.19  7.19  8.    6.39  5.6
#   2.    2.    2.    2.    2.    4.    4.    4.    4.    4.    4.    4.39
#   5.6   6.    2.    2.    2.    4.    4.    2.    2.    2.8   4.    2.8
#   4.    4.    4.    4.    4.    2.    2.    2.8   2.    2.8   4.    4.
#   4.    4.    4.39  4.39  5.6   4.39  5.6   5.6   5.6   4.39  4.39  4.39
#   5.6   6.    6.    6.    8.    8.    7.19  6.39  4.39  6.    4.    4.39
#   6.    6.39  6.39  7.19  7.19  7.19  6.39  7.19  8.    8.    8.    8.
#   6.    6.    6.39  5.6   6.39  5.6   5.6   6.39  7.19  8.39  8.    8.79
#   9.99  8.79  8.    8.39  7.19  7.19  7.19  7.19  8.39  8.4   8.39  8.79
#   8.    5.6   6.39  6.39  7.19  6.39  6.39  6.39  6.    6.39  7.19  7.19
#   8.39  8.4   8.79  8.    8.39  8.39  8.    7.19  8.4   8.39  6.    6.
# ...
